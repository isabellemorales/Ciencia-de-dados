# %% [markdown]
# <a href="https://colab.research.google.com/github/isabellemorales/Ciencia-de-dados/blob/main/DataSCiencester.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. ENCONTRANDO CONECTORES - CHAVES ENTRE OS CIENTISTAS DE DADOS, PRIMEIRO VAMOS CRIAR A ESTRUTURA CONTENDO AS INFORMAÇÕES DOS CIENTISTAS

# %%
users = [
    {"id":0, 'nome':"Hero"},
    {"id":1, 'nome':"Dunn"},
    {"id":2, 'nome':"Sue"},
    {"id":3, 'nome':"Chi"},
    {"id":4, "name":"Thor"},
    {"id":5, 'nome':"Clive"},
    {"id":6, 'nome':"Hics"},
    {"id":7, "name":"Devin"},
    {"id":8, 'nome':"Kate"},
    {"id":9, "name":"Klein"},
]

# %% [markdown]
# 2. Agora vamos montar a relação entre os cientistas, para isso, vamos criar uma lista de pares de IDS

# %%
friendship = [(0,1), (0,2),(1,2),(1,3),(2,3),(3,4),(4,5),(5,6),(5,7),(6,8),(7,8),(8,9)]

# %% [markdown]
# 3. Podemos adicionar uma lista de amigos para cada usuário. Primeiro, vamos configurar a propriedade friends de cada usuário em uma lista vazia

# %%
for user in users:
  user ["friends"]=[]

# %% [markdown]
# 4. Verifique o dicionário users

# %%
users
# Out:
# [{'id': 0, 'nome': 'Hero', 'friends': []},
#  {'id': 1, 'nome': 'Dunn', 'friends': []},
#  {'id': 2, 'nome': 'Sue', 'friends': []},
#  {'id': 3, 'nome': 'Chi', 'friends': []},
#  {'id': 4, 'name': 'Thor', 'friends': []},
#  {'id': 5, 'nome': 'Clive', 'friends': []},
#  {'id': 6, 'nome': 'Hics', 'friends': []},
#  {'id': 7, 'name': 'Devin', 'friends': []},
#  {'id': 8, 'nome': 'Kate', 'friends': []},
#  {'id': 9, 'name': 'Klein', 'friends': []}]

# %% [markdown]
# 5.Agora vamos popular a lista com os dados de friendship

# %%
for i, j in friendship:
  #isto vai funcionar por user[i]é o usuário cuja id é i
  users[i]["friends"].append(users[j])#adicionando i como um amigo de j
  users[j]["friends"].append(users[i])#adicionando j como um amigo de i

# %% [markdown]
# 6. Vamos verificar como ficou users

# %%
users
# Out:
# [{'id': 0,
#   'nome': 'Hero',
#   'friends': [{'id': 1,
#     'nome': 'Dunn',
#     'friends': [{...},
#      {'id': 2,
#       'nome': 'Sue',
#       'friends': [{...},
#        {...},
#        {'id': 3,
#         'nome': 'Chi',
#         'friends': [{...},
#          {...},
#          {'id': 4,
#           'name': 'Thor',
#           'friends': [{...},
#            {'id': 5,
#             'nome': 'Clive',
#             'friends': [{...},
#              {'id': 6,
#               'nome': 'Hics',
#               'friends': [{...},
#                {'id': 8,
#                 'nome': 'Kate',
#                 'friends': [{...},
#                  {'id': 7, 'name': 'Devin', 'friends': [{...}, {...}]},
#                  {'id': 9, 'name': 'Klein', 'friends': [{...}]}]}]},
#              {'id': 7,
#               'name': 'Devin',
#               'friends': [{...},
#                {'id': 8,
#                 'nome': 'Kate',
#                 'friends': [{'id': 6,
# ...
